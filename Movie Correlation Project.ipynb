# %%
#Importing Libraries

import pandas as pd
import numpy as np
import seaborn as sns 

import matplotlib
import matplotlib.pyplot as plt 
plt.style.use('ggplot')
from matplotlib.pyplot import figure


# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) #Adjusting the configuration of plots

# %%
df= pd.read_csv(r'E:\Port_Projects\python projects\movies_dataset\movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# percentage of missing values for every column
for col in df.columns:
    percent_missing=np.mean(df[col].isnull())*100 
    print('{} - {}%'.format(col, round(percent_missing)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# handling missing values before changing datatype
df['budget']= df['budget'].fillna(0)
df['gross']= df['gross'].fillna(0)

# %%
# datatypes of coulmns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# changing datatypes
df['budget']= df['budget'].astype('int64')
df['gross']= df['gross'].astype('int64')

# %%
#extracting year from the df[released] column as df[year] column doesn't match completely with df[released] one 
df['correct_year'] = df['released'].str.extract(pat = '([0-9]{4})')
# Fill NaN values with a placeholder, then convert to integer
df['correct_year'] = df['correct_year'].fillna(0).astype(int)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df.sort_values(by=['gross'], ascending=False, inplace=False)
# Out:
#                                             name rating    genre  year  \
# 5445                                      Avatar  PG-13   Action  2009
# 7445                           Avengers: Endgame  PG-13   Action  2019
# 3045                                     Titanic  PG-13    Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13   Action  2015
# 7244                      Avengers: Infinity War  PG-13   Action  2018
# ...                                          ...    ...      ...   ...
# 1617                             Mortal Passions      R    Crime  1989
# 1614                              Edge of Sanity      R   Horror  1989
# 1606                                   I, Madman      R  Fantasy  1989
# 1601                        My Twentieth Century    NaN   Comedy  1989
# 7667                                   Tee em el    NaN   Horror  2020
#
#                                released  score      votes        director  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.drop_duplicates().head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  correct_year
# 0  1047       54  19000000   46998772     2319    146.0          1980
# 1   327       55   4500000   58853106      731    104.0          1980
# 2  1745       55  18000000  538375067     1540    124.0          1980
# 3  2246       55   3500000   83453539     1812     88.0          1980
# 4   410       55   6000000   39846344     1777     98.0          1980

# %%
# High correlation of gross with budget  
# High correlation of gross with company

# %%
plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget Vs Gross Earnings')

plt.xlabel('Gross Earnings')
plt.ylabel('Budget For Film')

plt.show()

# %%
# Regression Plot budget vs gross
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color': 'red'}, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# correlation in data

numeric_df=df.select_dtypes(np.number)

correlation_matrix= numeric_df.corr(method= 'pearson')
correlation_matrix
# Out:
#                   year     score     votes    budget     gross   runtime  \
# year          1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score         0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes         0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget        0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross         0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime       0.120811  0.399451  0.309212  0.269510  0.245235  1.000000
# correct_year  0.312521  0.045473  0.070314  0.108069  0.090394  0.120636
#
#               correct_year
# year              0.312521
# score             0.045473
# votes             0.070314
# budget            0.108069
# gross             0.090394
# runtime           0.120636
# correct_year      1.000000

# %%
correlation_matrix= numeric_df.corr(method= 'pearson')
sns.heatmap(correlation_matrix, annot= True)

plt.title('Correlation Matric For Numeric Features')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# looking at company
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numerized=df
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtypes == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] =df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  correct_year
# 0  1047       54  19000000   46998772     2319    146.0          1980
# 1   327       55   4500000   58853106      731    104.0          1980
# 2  1745       55  18000000  538375067     1540    124.0          1980
# 3  2246       55   3500000   83453539     1812     88.0          1980
# 4   410       55   6000000   39846344     1777     98.0          1980

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  correct_year
# 0  1047       54  19000000   46998772     2319    146.0          1980
# 1   327       55   4500000   58853106      731    104.0          1980
# 2  1745       55  18000000  538375067     1540    124.0          1980
# 3  2246       55   3500000   83453539     1812     88.0          1980
# 4   410       55   6000000   39846344     1777     98.0          1980

# %%
correlation_matrix= df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matric For Numeric Features')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# getting highest correlating features
df_numerized.corr()
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating       -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre         0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year          0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released     -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score         0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes         0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director      0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer        0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star          0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country      -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget        0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# ...

# %%
corr_matrix=df_numerized.corr()

corr_pairs=corr_matrix.unstack()

corr_pairs
# Out:
# name          name            1.000000
#               rating         -0.008069
#               genre           0.016355
#               year            0.011453
#               released       -0.011311
#                                 ...
# correct_year  budget          0.108069
#               gross           0.090394
#               company         0.025615
#               runtime         0.120636
#               correct_year    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs= corr_pairs.sort_values()
sorted_pairs
# Out:
# budget        genre          -0.334021
# genre         budget         -0.334021
# gross         genre          -0.234297
# genre         gross          -0.234297
#               votes          -0.145307
#                                 ...
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# correct_year  correct_year    1.000000
# Length: 256, dtype: float64

# %%
high_corr_pairs = sorted_pairs[sorted_pairs>0.5]
high_corr_pairs
# Out:
# gross         votes           0.632834
# votes         gross           0.632834
# budget        gross           0.750157
# gross         budget          0.750157
# name          name            1.000000
# company       company         1.000000
# gross         gross           1.000000
# budget        budget          1.000000
# country       country         1.000000
# star          star            1.000000
# writer        writer          1.000000
# director      director        1.000000
# votes         votes           1.000000
# score         score           1.000000
# released      released        1.000000
# year          year            1.000000
# genre         genre           1.000000
# rating        rating          1.000000
# runtime       runtime         1.000000
# correct_year  correct_year    1.000000
# dtype: float64

# %%
# Final visualization of the correlation matrix with high correlations highlighted


sns.heatmap(correlation_matrix, annot=True, linewidths=0.5, mask=np.triu(correlation_matrix))
plt.title('Final Visualization: Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#votes and Budget gas the highest correlation to gross earnings
#company has low correlation
